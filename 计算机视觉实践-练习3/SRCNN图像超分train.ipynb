# %%
from math import exp, log10
from os import listdir
from os.path import join
import torch
from PIL import Image
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# %%
def is_image_file(filename):
    return any(filename.endswith(extension) for extension in [".png", ".jpg", ".jpeg"])

# 读取图像转为YCbCr模式，得到Y通道
def load_img(filepath):
    img = Image.open(filepath).convert('YCbCr')
    y, _, _ = img.split()
    return y

# 裁剪大小，宽高一致为300
# 如果想训练自己的数据集，请根据情况修改裁剪大小
CROP_SIZE = 300

# 封装数据集，适配后面的torch.utils.data.DataLoader中的dataset，定义成类似形式
# 类参数为图像文件夹路径和放大倍数
# __len__(self) 定义当被len()函数调用时的行为（返回容器中元素的个数）
#__getitem__(self) 定义获取容器中指定元素的行为，相当于self[key]，即允许类对象可以有索引操作。
#__iter__(self) 定义当迭代容器中的元素的行为
# 返回输入图像和标签，传入DataLoader的dataset参数
class DatasetFromFolder(Dataset):
    def __init__(self, image_dir, zoom_factor):
        super(DatasetFromFolder, self).__init__()
        self.image_filenames = [join(image_dir, x) for x in listdir(image_dir) if is_image_file(x)] # 图像路径列表
        crop_size = CROP_SIZE - (CROP_SIZE % zoom_factor) # 处理放大倍数，防止用户瞎设置，本例只能设置为2，3，4，大小不变
        # 数据集变换
        # 还有一些其他的变换操作，如归一化等，遇到一个积累一个
        self.input_transform = transforms.Compose([transforms.CenterCrop(crop_size), # 从图片中心裁剪成300*300
                                                   transforms.Resize(
                                                       crop_size // zoom_factor),    # Resize, 输入应该是缩放倍数后的图像，因为先缩小后放大
                                                   transforms.Resize(
                                                       crop_size, interpolation=Image.BICUBIC), # 双三次插值
                                                   transforms.ToTensor()]) # 图像转成tensor
        # label标签，超分不是分类问题，定义成一样的就行
        self.target_transform = transforms.Compose(
            [transforms.CenterCrop(crop_size), transforms.ToTensor()])

    def __getitem__(self, index):
        input = load_img(self.image_filenames[index]) # 输入是图像的Y通道，即亮度通道
        target = input.copy()
        input = self.input_transform(input)
        target = self.target_transform(target)
        return input, target

    def __len__(self):
        return len(self.image_filenames) # 图像个数

# %%
"""
计算ssim函数
"""


# 计算一维的高斯分布向量
def gaussian(window_size, sigma):
    gauss = torch.Tensor(
        [exp(-(x - window_size // 2) ** 2 / float(2 * sigma ** 2)) for x in range(window_size)])
    return gauss / gauss.sum()


# 创建高斯核，通过两个一维高斯分布向量进行矩阵乘法得到
# 可以设定channel参数拓展为3通道
def create_window(window_size, channel=1):
    _1D_window = gaussian(window_size, 1.5).unsqueeze(1)
    _2D_window = _1D_window.mm(
        _1D_window.t()).float().unsqueeze(0).unsqueeze(0)
    window = _2D_window.expand(
        channel, 1, window_size, window_size).contiguous()
    return window


def psnr(loss):
    return 10 * log10(1 / loss.item())

# 计算SSIM
# 直接使用SSIM的公式，但是在计算均值时，不是直接求像素平均值，而是采用归一化的高斯核卷积来代替。
# 在计算方差和协方差时用到了公式Var(X)=E[X^2]-E[X]^2, cov(X,Y)=E[XY]-E[X]E[Y].
def ssim(img1, img2, window_size=11, window=None, size_average=True, full=False, val_range=None):
    # Value range can be different from 255. Other common ranges are 1 (sigmoid) and 2 (tanh).
    if val_range is None:
        if torch.max(img1) > 128:
            max_val = 255
        else:
            max_val = 1

        if torch.min(img1) < -0.5:
            min_val = -1
        else:
            min_val = 0
        L = max_val - min_val
    else:
        L = val_range

    padd = 0
    (_, channel, height, width) = img1.size()
    if window is None:
        real_size = min(window_size, height, width)
        window = create_window(real_size, channel=channel).to(img1.device)

    # 图像卷积后的均值
    mu1 = F.conv2d(img1, window, padding=padd, groups=channel)
    mu2 = F.conv2d(img2, window, padding=padd, groups=channel)

    # 均值平方
    mu1_sq = mu1.pow(2)
    mu2_sq = mu2.pow(2)
    mu1_mu2 = mu1 * mu2

    # 方差
    sigma1_sq = F.conv2d(img1 * img1, window, padding=padd,
                         groups=channel) - mu1_sq
    sigma2_sq = F.conv2d(img2 * img2, window, padding=padd,
                         groups=channel) - mu2_sq
    sigma12 = F.conv2d(img1 * img2, window, padding=padd,
                       groups=channel) - mu1_mu2

    # SSIM默认常数
    C1 = (0.01 * L) ** 2
    C2 = (0.03 * L) ** 2

    v1 = 2.0 * sigma12 + C2
    v2 = sigma1_sq + sigma2_sq + C2
    cs = torch.mean(v1 / v2)  # contrast sensitivity

    ssim_map = ((2 * mu1_mu2 + C1) * v1) / ((mu1_sq + mu2_sq + C1) * v2)

    # 平均SSIM
    if size_average:
        ret = ssim_map.mean()
    else:
        ret = ssim_map.mean(1).mean(1).mean(1)

    if full:
        return ret, cs
    return ret


# 封装成类
class SSIM(torch.nn.Module):
    def __init__(self, window_size=11, size_average=True, val_range=None):
        super(SSIM, self).__init__()
        self.window_size = window_size
        self.size_average = size_average
        self.val_range = val_range

        # Assume 1 channel for SSIM
        self.channel = 1
        self.window = create_window(window_size)

    def forward(self, img1, img2):
        (_, channel, _, _) = img1.size()

        if channel == self.channel and self.window.dtype == img1.dtype:
            window = self.window
        else:
            window = create_window(self.window_size, channel).to(
                img1.device).type(img1.dtype)
            self.window = window
            self.channel = channel

        return ssim(img1, img2, window=window, window_size=self.window_size, size_average=self.size_average)

# %%
# 搭建SRCNN
class SRCNN(nn.Module):
    def __init__(self, upscale_factor):
        super(SRCNN, self).__init__()

        self.relu = nn.ReLU()
        self.conv1 = nn.Conv2d(1, 64, kernel_size=9, padding=9//2)
        self.conv2 = nn.Conv2d(64, 32, kernel_size=1)
        self.conv3 = nn.Conv2d(32, 1, kernel_size=5, padding=5//2)
        self.pixel_shuffle = nn.PixelShuffle(upscale_factor)

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu(x)
        x = self.conv2(x)
        x = self.relu(x)
        x = self.conv3(x)
        x = self.pixel_shuffle(x)
        return x

# %%
# 放大倍数
zoom_factor = 3
nb_epochs = 500
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.manual_seed(0)
torch.cuda.manual_seed(0)
BATCH_SIZE = 4
NUM_WORKERS = 0
trainset = DatasetFromFolder(r"E:\BSDS300-images\BSDS300\images\train", zoom_factor)
valset = DatasetFromFolder(r"E:\BSDS300-images\BSDS300\images\train", zoom_factor)
trainloader = DataLoader(dataset=trainset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
valloader = DataLoader(dataset=valset, batch_size=BATCH_SIZE,
                       shuffle=False, num_workers=NUM_WORKERS)

model = SRCNN(1).to(device)  # 模型，net.to(device)保证用GPU训练，本地训练可以不加，服务器上一定要加
criterion = nn.MSELoss()  # 损失函数为MSE
optimizer = optim.Adam(
    [
        {"params": model.conv1.parameters(), "lr": 0.0001},
        {"params": model.conv2.parameters(), "lr": 0.0001},
        {"params": model.conv3.parameters(), "lr": 0.00001},
    ]
)  # Adam优化器，设定三个层学习率为论文中的值，最后一层更小
# 一般的优化器传参就是optim.Adam(lr=0.0001), 因为最后一层学习率不同，所以用字典形式传参。
# Out:
# D:\Anaconda3\envs\SRCNN\lib\site-packages\torchvision\transforms\transforms.py:280: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(

# %%
best_psnr = 0.0
for epoch in range(nb_epochs):
    # 训练
    epoch_loss = 0
    for iteration, batch in enumerate(trainloader):  # batchsize为4，则trainloader的长度是50，遍历它
        input, target = batch[0].to(device), batch[1].to(device)  # 每个trainloader是由图像张量和标签构成
        optimizer.zero_grad()  # 训练经典三步第一步：梯度归零
        out = model(input)  # 输入模型得到输出
        loss = criterion(out, target)  # 计算损失
        loss.backward()  # 训练经典三步第二步：反向传播
        optimizer.step()  # 训练经典三步第三步：梯度下降，更新一步参数
        epoch_loss += loss.item()  # 累加损失
    print(f"Epoch {epoch}. Training loss: {epoch_loss / len(trainloader)}")  # 训练完计算损失
# Out:
# Epoch 0. Training loss: 0.22559629157185554
# Epoch 1. Training loss: 0.06908052768558264
# Epoch 2. Training loss: 0.009506322834640741
# Epoch 3. Training loss: 0.008707433631643653
# Epoch 4. Training loss: 0.008004619562998415
# Epoch 5. Training loss: 0.007428309861570597
# Epoch 6. Training loss: 0.00686546387616545
# Epoch 7. Training loss: 0.006182491299696267
# Epoch 8. Training loss: 0.005528760552406311
# Epoch 9. Training loss: 0.005101262568496167
# Epoch 10. Training loss: 0.004843900313135236
# Epoch 11. Training loss: 0.004683062289841473
# Epoch 12. Training loss: 0.004543563791085035
# Epoch 13. Training loss: 0.004416957129724324
# Epoch 14. Training loss: 0.004303831227589399
# Epoch 15. Training loss: 0.004198305427562446
# Epoch 16. Training loss: 0.004102836740203202
# Epoch 17. Training loss: 0.004010234549641609
# Epoch 18. Training loss: 0.003925529937259853
# Epoch 19. Training loss: 0.0038497459492646156
# Epoch 20. Training loss: 0.0037847025645896793
# Epoch 21. Training loss: 0.003727935783099383
# Epoch 22. Training loss: 0.00367864313069731
# Epoch 23. Training loss: 0.003635696030687541
# Epoch 24. Training loss: 0.0035976192029193044
# Epoch 25. Training loss: 0.0035641187569126487
# Epoch 26. Training loss: 0.0035344535275362433
# Epoch 27. Training loss: 0.0035091336607001723
# Epoch 28. Training loss: 0.0034878911287523806
# Epoch 29. Training loss: 0.003467290692497045
# Epoch 30. Training loss: 0.0034512339998036623
# Epoch 31. Training loss: 0.003435183269903064
# Epoch 32. Training loss: 0.0034217332117259503
# Epoch 33. Training loss: 0.003409010022878647
# Epoch 34. Training loss: 0.0033969183173030615
# Epoch 35. Training loss: 0.0033859818312339486
# Epoch 36. Training loss: 0.0033774189767427744
# Epoch 37. Training loss: 0.003367230745498091
# Epoch 38. Training loss: 0.003359102655667812
# Epoch 39. Training loss: 0.003350546029396355
# Epoch 40. Training loss: 0.003342765204142779
# Epoch 41. Training loss: 0.0033347472455352543
# Epoch 42. Training loss: 0.003327653338201344
# Epoch 43. Training loss: 0.003322989484295249
# Epoch 44. Training loss: 0.0033172217989340426
# Epoch 45. Training loss: 0.0033088031620718537
# Epoch 46. Training loss: 0.003302746822591871
# Epoch 47. Training loss: 0.003297893188428134
# Epoch 48. Training loss: 0.003292335344012827
# Epoch 49. Training loss: 0.003287039045244455
# Epoch 50. Training loss: 0.003283469311427325
# Epoch 51. Training loss: 0.003277664401102811
# Epoch 52. Training loss: 0.0032722953101620078
# Epoch 53. Training loss: 0.003267665307503194
# Epoch 54. Training loss: 0.0032634470192715527
# Epoch 55. Training loss: 0.0032634957530535756
# Epoch 56. Training loss: 0.0032546105701476338
# Epoch 57. Training loss: 0.0032503536995500326
# Epoch 58. Training loss: 0.0032461311458609997
# Epoch 59. Training loss: 0.0032421715138480065
# Epoch 60. Training loss: 0.0032386155403219164
# Epoch 61. Training loss: 0.0032344039948657157
# Epoch 62. Training loss: 0.0032302023097872733
# Epoch 63. Training loss: 0.003226154166040942
# Epoch 64. Training loss: 0.003221675637178123
# Epoch 65. Training loss: 0.0032151551521383227
# Epoch 66. Training loss: 0.0032093695434741677
# Epoch 67. Training loss: 0.0032049754122272134
# Epoch 68. Training loss: 0.003200793347787112
# Epoch 69. Training loss: 0.0031971107120625673
# Epoch 70. Training loss: 0.003193211785983294
# Epoch 71. Training loss: 0.0031907790491823105
# Epoch 72. Training loss: 0.0031861045281402767
# Epoch 73. Training loss: 0.0031815129029564558
# Epoch 74. Training loss: 0.003178319347789511
# Epoch 75. Training loss: 0.0031739855161868036
# Epoch 76. Training loss: 0.0031710372073575853
# Epoch 77. Training loss: 0.0031677677831612526
# Epoch 78. Training loss: 0.0031700824038125575
# Epoch 79. Training loss: 0.0031678581971209497
# Epoch 80. Training loss: 0.003159532768186182
# Epoch 81. Training loss: 0.0031566553260199727
# Epoch 82. Training loss: 0.0031542542087845504
# Epoch 83. Training loss: 0.0031519850320182743
# Epoch 84. Training loss: 0.003149740286171436
# Epoch 85. Training loss: 0.003147504823282361
# Epoch 86. Training loss: 0.003145434590987861
# Epoch 87. Training loss: 0.0031435433425940572
# Epoch 88. Training loss: 0.003141003791242838
# Epoch 89. Training loss: 0.0031389120221138
# Epoch 90. Training loss: 0.003137089910451323
# Epoch 91. Training loss: 0.0031349926302209497
# Epoch 92. Training loss: 0.0031335584400221704
# Epoch 93. Training loss: 0.003131161031778902
# Epoch 94. Training loss: 0.0031294592167250813
# Epoch 95. Training loss: 0.0031275539915077387
# Epoch 96. Training loss: 0.0031278520589694382
# Epoch 97. Training loss: 0.0031268983031623064
# Epoch 98. Training loss: 0.0031223269551992417
# Epoch 99. Training loss: 0.0031206850009039043
# Epoch 100. Training loss: 0.0031192633509635925
# Epoch 101. Training loss: 0.0031179431523196397
# Epoch 102. Training loss: 0.0031165042216889562
# Epoch 103. Training loss: 0.003114906733389944
# Epoch 104. Training loss: 0.0031135996663942934
# Epoch 105. Training loss: 0.0031128599354997275
# Epoch 106. Training loss: 0.003111365681979805
# Epoch 107. Training loss: 0.0031095536041539163
# Epoch 108. Training loss: 0.003108380017802119
# Epoch 109. Training loss: 0.0031076360028237104
# Epoch 110. Training loss: 0.0031061940803192556
# Epoch 111. Training loss: 0.0031048660003580152
# Epoch 112. Training loss: 0.0031036315415985884
# Epoch 113. Training loss: 0.0031028220313601197
# Epoch 114. Training loss: 0.0031015192181803285
# Epoch 115. Training loss: 0.0031003352743573485
# Epoch 116. Training loss: 0.0031001902371644973
# Epoch 117. Training loss: 0.0030982165155000983
# Epoch 118. Training loss: 0.003097755137132481
# Epoch 119. Training loss: 0.00309726198669523
# Epoch 120. Training loss: 0.003096539513207972
# Epoch 121. Training loss: 0.003097794419154525
# Epoch 122. Training loss: 0.003096556239761412
# Epoch 123. Training loss: 0.003093414445174858
# Epoch 124. Training loss: 0.0030920933419838546
# Epoch 125. Training loss: 0.003091311496682465
# Epoch 126. Training loss: 0.0030906995362602174
# Epoch 127. Training loss: 0.0030899127828888594
# Epoch 128. Training loss: 0.0030893380451016126
# Epoch 129. Training loss: 0.0030918424820993097
# Epoch 130. Training loss: 0.0030891201144549996
# Epoch 131. Training loss: 0.003097121557220817
# Epoch 132. Training loss: 0.003094858580734581
# Epoch 133. Training loss: 0.0030858905659988524
# Epoch 134. Training loss: 0.003085157400928438
# Epoch 135. Training loss: 0.0030844620265997945
# Epoch 136. Training loss: 0.003084666058421135
# Epoch 137. Training loss: 0.003083768002688885
# Epoch 138. Training loss: 0.003083332774695009
# Epoch 139. Training loss: 0.003082471422385424
# Epoch 140. Training loss: 0.0030816674733068795
# Epoch 141. Training loss: 0.0030819958774372935
# Epoch 142. Training loss: 0.0030965515691787006
# Epoch 143. Training loss: 0.0030817538197152315
# Epoch 144. Training loss: 0.003080031992867589
# Epoch 145. Training loss: 0.003080350605305284
# Epoch 146. Training loss: 0.003078731442801654
# Epoch 147. Training loss: 0.0030779310408979655
# Epoch 148. Training loss: 0.003077503489330411
# Epoch 149. Training loss: 0.003076996966265142
# Epoch 150. Training loss: 0.003076409512432292
# Epoch 151. Training loss: 0.0030761289014481006
# Epoch 152. Training loss: 0.003075163464527577
# Epoch 153. Training loss: 0.003074749561492354
# Epoch 154. Training loss: 0.0030742047587409616
# Epoch 155. Training loss: 0.0030785583378747108
# Epoch 156. Training loss: 0.0030761523032560942
# Epoch 157. Training loss: 0.003074895334430039
# Epoch 158. Training loss: 0.0030720455991104247
# Epoch 159. Training loss: 0.0030722506809979675
# Epoch 160. Training loss: 0.0030715156439691783
# Epoch 161. Training loss: 0.003070577357430011
# Epoch 162. Training loss: 0.0030703682696912437
# Epoch 163. Training loss: 0.0030695726606063544
# Epoch 164. Training loss: 0.0030693906056694685
# Epoch 165. Training loss: 0.0030685468576848508
# Epoch 166. Training loss: 0.003068232452496886
# Epoch 167. Training loss: 0.0030672072758898138
# Epoch 168. Training loss: 0.0030680560716427863
# Epoch 169. Training loss: 0.0030671345198061317
# Epoch 170. Training loss: 0.0030659750662744047
# Epoch 171. Training loss: 0.0030674142809584736
# Epoch 172. Training loss: 0.003065061084926128
# Epoch 173. Training loss: 0.003064155273605138
# Epoch 174. Training loss: 0.0030633554281666877
# Epoch 175. Training loss: 0.0030632326169870794
# Epoch 176. Training loss: 0.0030630310624837876
# Epoch 177. Training loss: 0.003067877269349992
# Epoch 178. Training loss: 0.0030701020802371202
# Epoch 179. Training loss: 0.0030623700097203253
# Epoch 180. Training loss: 0.003061582564841956
# Epoch 181. Training loss: 0.0030640897783450784
# Epoch 182. Training loss: 0.003061113462317735
# Epoch 183. Training loss: 0.003060014075599611
# Epoch 184. Training loss: 0.0030587720358744262
# Epoch 185. Training loss: 0.003058509191032499
# Epoch 186. Training loss: 0.0030607686075381935
# Epoch 187. Training loss: 0.0030617499654181303
# Epoch 188. Training loss: 0.0030768929701298475
# Epoch 189. Training loss: 0.003060663905926049
# Epoch 190. Training loss: 0.00305627383524552
# Epoch 191. Training loss: 0.0030561886937357486
# Epoch 192. Training loss: 0.0030551776848733426
# Epoch 193. Training loss: 0.0030558927555102856
# Epoch 194. Training loss: 0.0030543928942643106
# Epoch 195. Training loss: 0.00305434005567804
# Epoch 196. Training loss: 0.003053559465333819
# Epoch 197. Training loss: 0.003053571728523821
# Epoch 198. Training loss: 0.0030528265866450965
# Epoch 199. Training loss: 0.0030522399907931684
# Epoch 200. Training loss: 0.0030520066688768566
# Epoch 201. Training loss: 0.0030514464247971772
# Epoch 202. Training loss: 0.003052249497268349
# Epoch 203. Training loss: 0.0030532057001255455
# Epoch 204. Training loss: 0.0030500963085796683
# Epoch 205. Training loss: 0.0030497591581661256
# Epoch 206. Training loss: 0.003050336395390332
# Epoch 207. Training loss: 0.0030494805262424054
# Epoch 208. Training loss: 0.003048110024537891
# Epoch 209. Training loss: 0.003047734244028106
# Epoch 210. Training loss: 0.003048345702700317
# Epoch 211. Training loss: 0.0030492117535322904
# Epoch 212. Training loss: 0.003047307054512203
# Epoch 213. Training loss: 0.0030465911759529262
# Epoch 214. Training loss: 0.0030468645133078097
# Epoch 215. Training loss: 0.0030472899181768296
# Epoch 216. Training loss: 0.0030447696242481472
# Epoch 217. Training loss: 0.003045634008012712
# Epoch 218. Training loss: 0.003045642718207091
# Epoch 219. Training loss: 0.003043519984930754
# Epoch 220. Training loss: 0.0030433738662395625
# Epoch 221. Training loss: 0.0030423739925026895
# Epoch 222. Training loss: 0.0030421981704421342
# Epoch 223. Training loss: 0.0030435244389809667
# Epoch 224. Training loss: 0.0030413154745474458
# Epoch 225. Training loss: 0.0030402526608668268
# Epoch 226. Training loss: 0.0030406063655391336
# Epoch 227. Training loss: 0.0030400009360164403
# Epoch 228. Training loss: 0.003038648774381727
# Epoch 229. Training loss: 0.0030383099359460176
# Epoch 230. Training loss: 0.0030397363007068634
# Epoch 231. Training loss: 0.003045563381165266
# Epoch 232. Training loss: 0.0030368048523087055
# Epoch 233. Training loss: 0.003036725432612002
# Epoch 234. Training loss: 0.003036176067544147
# Epoch 235. Training loss: 0.0030356615432538094
# Epoch 236. Training loss: 0.003036491968668997
# Epoch 237. Training loss: 0.0030565267032943667
# Epoch 238. Training loss: 0.0030375201278366147
# Epoch 239. Training loss: 0.003033667515264824
# Epoch 240. Training loss: 0.003032835302874446
# Epoch 241. Training loss: 0.003031784864142537
# Epoch 242. Training loss: 0.0030312459962442517
# Epoch 243. Training loss: 0.0030311655020341275
# Epoch 244. Training loss: 0.0030306978640146556
# Epoch 245. Training loss: 0.003029995176475495
# Epoch 246. Training loss: 0.003029431808972731
# Epoch 247. Training loss: 0.003029750930145383
# Epoch 248. Training loss: 0.003029185002669692
# Epoch 249. Training loss: 0.003027724204584956
# Epoch 250. Training loss: 0.0030271689873188736
# Epoch 251. Training loss: 0.0030274965707212686
# Epoch 252. Training loss: 0.003026338049676269
# Epoch 253. Training loss: 0.0030261689238250257
# Epoch 254. Training loss: 0.0030256414879113436
# Epoch 255. Training loss: 0.003024320004042238
# Epoch 256. Training loss: 0.0030294806649908425
# Epoch 257. Training loss: 0.003030665523838252
# Epoch 258. Training loss: 0.0030232464987784624
# Epoch 259. Training loss: 0.003022180723492056
# Epoch 260. Training loss: 0.0030218985420651734
# Epoch 261. Training loss: 0.0030281021632254123
# Epoch 262. Training loss: 0.0030243373522534965
# Epoch 263. Training loss: 0.0030211330018937587
# Epoch 264. Training loss: 0.0030206147325225175
# Epoch 265. Training loss: 0.003019946641288698
# Epoch 266. Training loss: 0.003019244084134698
# Epoch 267. Training loss: 0.003018648368306458
# Epoch 268. Training loss: 0.0030190840060822666
# Epoch 269. Training loss: 0.003018162914086133
# Epoch 270. Training loss: 0.0030181050644023343
# Epoch 271. Training loss: 0.003016703356988728
# Epoch 272. Training loss: 0.0030170082463882864
# Epoch 273. Training loss: 0.0030174019280821084
# Epoch 274. Training loss: 0.0030159048235509547
# Epoch 275. Training loss: 0.00301551946438849
# Epoch 276. Training loss: 0.003016191655769944
# Epoch 277. Training loss: 0.003014687458053231
# Epoch 278. Training loss: 0.0030185999372042715
# Epoch 279. Training loss: 0.003015274074859917
# Epoch 280. Training loss: 0.003014796425122768
# Epoch 281. Training loss: 0.0030132836406119167
# Epoch 282. Training loss: 0.0030123142467346044
# Epoch 283. Training loss: 0.003011842733249068
# Epoch 284. Training loss: 0.003014090454671532
# Epoch 285. Training loss: 0.0030130764050409196
# Epoch 286. Training loss: 0.0030112500744871795
# Epoch 287. Training loss: 0.0030107873678207396
# Epoch 288. Training loss: 0.0030115282535552977
# Epoch 289. Training loss: 0.0030120793683454396
# Epoch 290. Training loss: 0.0030096534732729197
# Epoch 291. Training loss: 0.0030089714471250775
# Epoch 292. Training loss: 0.0030083238321822136
# Epoch 293. Training loss: 0.003008296610787511
# Epoch 294. Training loss: 0.003008397554513067
# Epoch 295. Training loss: 0.0030100301839411257
# Epoch 296. Training loss: 0.003014256008900702
# Epoch 297. Training loss: 0.003007470078300685
# Epoch 298. Training loss: 0.0030071655369829386
# Epoch 299. Training loss: 0.003007212474476546
# Epoch 300. Training loss: 0.0030139166256412863
# Epoch 301. Training loss: 0.0030071013676933943
# Epoch 302. Training loss: 0.00301229934906587
# Epoch 303. Training loss: 0.0030235908040776847
# Epoch 304. Training loss: 0.003004713406553492
# Epoch 305. Training loss: 0.0030047648400068285
# Epoch 306. Training loss: 0.0030043202266097067
# Epoch 307. Training loss: 0.0030033377883955836
# Epoch 308. Training loss: 0.0030029881768859922
# Epoch 309. Training loss: 0.0030034475051797928
# Epoch 310. Training loss: 0.0030026924144476654
# Epoch 311. Training loss: 0.0030022420873865485
# Epoch 312. Training loss: 0.0030023067491129042
# Epoch 313. Training loss: 0.0030019164737313986
# Epoch 314. Training loss: 0.003002953596878797
# Epoch 315. Training loss: 0.003002438663970679
# Epoch 316. Training loss: 0.0030093015334568918
# Epoch 317. Training loss: 0.0030013355042319747
# Epoch 318. Training loss: 0.003001404212554917
# Epoch 319. Training loss: 0.003001143776345998
# Epoch 320. Training loss: 0.0029995493101887404
# Epoch 321. Training loss: 0.0030022103479132056
# Epoch 322. Training loss: 0.003000621118117124
# Epoch 323. Training loss: 0.0030013491841964423
# Epoch 324. Training loss: 0.0030004371399991216
# Epoch 325. Training loss: 0.002998830972937867
# Epoch 326. Training loss: 0.003000450269319117
# Epoch 327. Training loss: 0.002998503444250673
# Epoch 328. Training loss: 0.002998342883074656
# Epoch 329. Training loss: 0.002998092626221478
# Epoch 330. Training loss: 0.002998838978819549
# Epoch 331. Training loss: 0.0029975954326801
# Epoch 332. Training loss: 0.002997803834732622
# Epoch 333. Training loss: 0.003001056187786162
# Epoch 334. Training loss: 0.003001145669259131
# Epoch 335. Training loss: 0.0029970168508589266
# Epoch 336. Training loss: 0.002996236742474139
# Epoch 337. Training loss: 0.002996028456836939
# Epoch 338. Training loss: 0.0029962451418396084
# Epoch 339. Training loss: 0.0029993944498710335
# Epoch 340. Training loss: 0.0029950096050743013
# Epoch 341. Training loss: 0.00299521544482559
# Epoch 342. Training loss: 0.0029953390802256764
# Epoch 343. Training loss: 0.0029948155384045094
# Epoch 344. Training loss: 0.0029943037626799195
# Epoch 345. Training loss: 0.0029950249381363392
# Epoch 346. Training loss: 0.002996319588273764
# Epoch 347. Training loss: 0.0030051523761358114
# Epoch 348. Training loss: 0.002995372212026268
# Epoch 349. Training loss: 0.0029942656308412554
# Epoch 350. Training loss: 0.0029925298364832996
# Epoch 351. Training loss: 0.002992048162268475
# Epoch 352. Training loss: 0.002991976928897202
# Epoch 353. Training loss: 0.002992033303016797
# Epoch 354. Training loss: 0.002995036927750334
# Epoch 355. Training loss: 0.003000099865021184
# Epoch 356. Training loss: 0.0030073615396395328
# Epoch 357. Training loss: 0.0029961147822905334
# Epoch 358. Training loss: 0.0029907689336687326
# Epoch 359. Training loss: 0.0029908980370964857
# Epoch 360. Training loss: 0.002990824063308537
# Epoch 361. Training loss: 0.002990310878958553
# Epoch 362. Training loss: 0.002989718767348677
# Epoch 363. Training loss: 0.002990235114702955
# Epoch 364. Training loss: 0.0029901740548666567
# Epoch 365. Training loss: 0.002990228505805135
# Epoch 366. Training loss: 0.0029899866273626684
# Epoch 367. Training loss: 0.00298878877190873
# Epoch 368. Training loss: 0.002989924035500735
# Epoch 369. Training loss: 0.0029889476858079435
# Epoch 370. Training loss: 0.002990354229696095
# Epoch 371. Training loss: 0.0029889851715415717
# Epoch 372. Training loss: 0.0029887993272859604
# Epoch 373. Training loss: 0.0029883902170695364
# Epoch 374. Training loss: 0.0029880656558088957
# Epoch 375. Training loss: 0.0029883136600255965
# Epoch 376. Training loss: 0.00298772954614833
# Epoch 377. Training loss: 0.00299264655681327
# Epoch 378. Training loss: 0.002997770004440099
# Epoch 379. Training loss: 0.0029875657486263664
# Epoch 380. Training loss: 0.0029880175460129978
# Epoch 381. Training loss: 0.0029870886146090925
# Epoch 382. Training loss: 0.0029867469356395305
# Epoch 383. Training loss: 0.002986058206297457
# Epoch 384. Training loss: 0.0029869649442844093
# Epoch 385. Training loss: 0.0029859286779537796
# Epoch 386. Training loss: 0.0029875655751675366
# Epoch 387. Training loss: 0.0029851855407468974
# Epoch 388. Training loss: 0.002985299421707168
# Epoch 389. Training loss: 0.002984903482720256
# Epoch 390. Training loss: 0.0029846582282334567
# Epoch 391. Training loss: 0.0029851809982210397
# Epoch 392. Training loss: 0.0029846663936041297
# Epoch 393. Training loss: 0.0029849332710728048
# Epoch 394. Training loss: 0.002984612786676735
# Epoch 395. Training loss: 0.0029849118285346777
# Epoch 396. Training loss: 0.002983354178722948
# Epoch 397. Training loss: 0.002985864344518632
# Epoch 398. Training loss: 0.0029840093525126577
# Epoch 399. Training loss: 0.0029851819411851467
# Epoch 400. Training loss: 0.003004531825426966
# Epoch 401. Training loss: 0.002982483971863985
# Epoch 402. Training loss: 0.002985982713289559
# Epoch 403. Training loss: 0.002983133851084858
# Epoch 404. Training loss: 0.0029820192593615503
# Epoch 405. Training loss: 0.0029830202553421258
# Epoch 406. Training loss: 0.002985027089016512
# Epoch 407. Training loss: 0.002983188934158534
# Epoch 408. Training loss: 0.002986128614284098
# Epoch 409. Training loss: 0.002981896330602467
# Epoch 410. Training loss: 0.002981541196350008
# Epoch 411. Training loss: 0.0029806397890206424
# Epoch 412. Training loss: 0.002983591938391328
# Epoch 413. Training loss: 0.002982106041163206
# Epoch 414. Training loss: 0.0029806834575720133
# Epoch 415. Training loss: 0.0029811191419139506
# Epoch 416. Training loss: 0.0029806051950436088
# Epoch 417. Training loss: 0.0029822091734968124
# Epoch 418. Training loss: 0.0029810248780995606
# Epoch 419. Training loss: 0.0029809386818669737
# Epoch 420. Training loss: 0.0029805513750761747
# Epoch 421. Training loss: 0.002979171467013657
# Epoch 422. Training loss: 0.002980586162302643
# Epoch 423. Training loss: 0.002979527822462842
# Epoch 424. Training loss: 0.002979773711413145
# Epoch 425. Training loss: 0.00298097190214321
# Epoch 426. Training loss: 0.0029783343756571413
# Epoch 427. Training loss: 0.002980562343727797
# Epoch 428. Training loss: 0.0029805378383025525
# Epoch 429. Training loss: 0.002977820714004338
# Epoch 430. Training loss: 0.0029787167720496653
# Epoch 431. Training loss: 0.002978792556095868
# Epoch 432. Training loss: 0.0029770370316691695
# Epoch 433. Training loss: 0.0029774968186393382
# Epoch 434. Training loss: 0.002978271911852062
# Epoch 435. Training loss: 0.0029779020044952633
# Epoch 436. Training loss: 0.0029771058284677565
# Epoch 437. Training loss: 0.002978206304833293
# Epoch 438. Training loss: 0.002988502569496632
# Epoch 439. Training loss: 0.0029857785883359612
# Epoch 440. Training loss: 0.00297744870884344
# Epoch 441. Training loss: 0.0029768232442438603
# Epoch 442. Training loss: 0.0029771999281365423
# Epoch 443. Training loss: 0.002975932981353253
# Epoch 444. Training loss: 0.0029763708589598536
# Epoch 445. Training loss: 0.0029770818073302507
# Epoch 446. Training loss: 0.0029776952345855535
# Epoch 447. Training loss: 0.0029766899906098843
# Epoch 448. Training loss: 0.0029815496783703564
# Epoch 449. Training loss: 0.0029759781528264284
# Epoch 450. Training loss: 0.0029753475147299467
# Epoch 451. Training loss: 0.0029767449386417866
# Epoch 452. Training loss: 0.002976148813031614
# Epoch 453. Training loss: 0.0029750695778056977
# Epoch 454. Training loss: 0.002973986091092229
# Epoch 455. Training loss: 0.0029747687734197827
# Epoch 456. Training loss: 0.002974570223595947
# Epoch 457. Training loss: 0.0029756292537786067
# Epoch 458. Training loss: 0.0029753149265889078
# Epoch 459. Training loss: 0.0029755700181704012
# Epoch 460. Training loss: 0.0029763576737605033
# Epoch 461. Training loss: 0.0029746939684264363
# Epoch 462. Training loss: 0.00297364701051265
# Epoch 463. Training loss: 0.0029740925831720235
# Epoch 464. Training loss: 0.0029767882672604175
# Epoch 465. Training loss: 0.002974987404886633
# Epoch 466. Training loss: 0.00298286703415215
# Epoch 467. Training loss: 0.0029730176087468863
# Epoch 468. Training loss: 0.0029726711253169925
# Epoch 469. Training loss: 0.002973185312002897
# Epoch 470. Training loss: 0.0029727641673525794
# Epoch 471. Training loss: 0.002972706325817853
# Epoch 472. Training loss: 0.0029731606878340244
# Epoch 473. Training loss: 0.0029718616721220313
# Epoch 474. Training loss: 0.0029731583711691202
# Epoch 475. Training loss: 0.002971560532459989
# Epoch 476. Training loss: 0.00297160972841084
# Epoch 477. Training loss: 0.002971568803768605
# Epoch 478. Training loss: 0.0029732155543752015
# Epoch 479. Training loss: 0.0029717907134909185
# Epoch 480. Training loss: 0.0029725456936284898
# Epoch 481. Training loss: 0.002971797089558095
# Epoch 482. Training loss: 0.0029707886814139784
# Epoch 483. Training loss: 0.0029715977213345466
# Epoch 484. Training loss: 0.002978271981701255
# Epoch 485. Training loss: 0.0029716330510564147
# Epoch 486. Training loss: 0.002970252864761278
# Epoch 487. Training loss: 0.0029701019683852792
# Epoch 488. Training loss: 0.002970617540413514
# Epoch 489. Training loss: 0.0029719628789462147
# Epoch 490. Training loss: 0.0029757233522832395
# Epoch 491. Training loss: 0.0029699593968689443
# Epoch 492. Training loss: 0.002970805133227259
# Epoch 493. Training loss: 0.0029695720411837103
# Epoch 494. Training loss: 0.0029718203248921783
# Epoch 495. Training loss: 0.0029701929073780776
# Epoch 496. Training loss: 0.0029692837712354957
# Epoch 497. Training loss: 0.0029688733571674674
# Epoch 498. Training loss: 0.0029707556241191924
# Epoch 499. Training loss: 0.002968379881931469

# %%
# 验证
sum_psnr = 0.0
sum_ssim = 0.0
with torch.no_grad():
    for batch in valloader:
        input, target = batch[0].to(device), batch[1].to(device)
        out = model(input)
        loss = criterion(out, target)
        pr = psnr(loss)
        sm = ssim(input, out)
        sum_psnr += pr
        sum_ssim += sm
print(f"Average PSNR: {sum_psnr / len(valloader)} dB.")
print(f"Average SSIM: {sum_ssim / len(valloader)} ")
avg_psnr = sum_psnr / len(valloader)
if avg_psnr >= best_psnr:
    best_psnr = avg_psnr  # 用psnr衡量模型，保存最好的
    torch.save(model, r"best_model_SRCNN_3.pth")
# Out:
# Average PSNR: 25.622924793060207 dB.
# Average SSIM: 0.9302493929862976
